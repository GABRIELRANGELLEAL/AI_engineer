# %% [markdown]
# # Testes do database
# Execute célula por célula para validar cada parte do agente.

# %%
import psycopg2
import pandas as pd
from datetime import datetime

# Database connection
conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="analytics",
    user="app",
    password="app"
)

# Create a cursor
cursor = conn.cursor()

# %%
query = """
SELECT table_name 
FROM information_schema.tables 
WHERE table_schema = 'public'
"""

df = pd.read_sql(query, conn)
df
# Out:
# C:\Users\thiag\AppData\Local\Temp\ipykernel_8768\3461807788.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#          table_name
# 0             tasks
# 1  llm_interactions

# %%
# All tasks
tasks_df = pd.read_sql("SELECT * FROM tasks ORDER BY created_at DESC", conn)
tasks_df
# Out:
# C:\Users\thiag\AppData\Local\Temp\ipykernel_8768\3973633542.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tasks_df = pd.read_sql("SELECT * FROM tasks ORDER BY created_at DESC", conn)
#                                      id  \
# 0  c6feb49d-f128-4800-8f6c-601dc92903dd
#
#                                     prompt      status data_source_type  \
# 0  can you help me to analyse my document?  plan_ready              csv
#
#                                                data_source_meta  \
# 0  {"csv_paths": ["uploads/20260601_171500_8827c032/data.csv"]}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  result  \
# 0  {"answer": "I've analyzed your CSV file containing 30 days of time-series data (Jan 1-30, 2023) with daily values ranging from 100-120. Here's a comprehensive plan to understand trends and patterns:", "plan": [{"step": 1, "description": "Load and validate the data", "rationale": "Ensure data integrity by checking for missing values, data types, and date continuity. This is the foundation for reliable analysis."}, {"step": 2, "description": "Calculate descriptive statistics", "rationale": "Generate mean, median, std dev, min, max to understand the overall distribution and variability of your values."}, {"step": 3, "description": "Analyze trend direction", "rationale": "Use linear regression or moving averages to identify if values are generally increasing, decreasing, or stable over the 30-day period."}, {"step": 4, "description": "Detect patterns and seasonality", "rationale": "Look for weekly cycles, repeating patterns, or day-of-week effects that might explain value fluctuations."}, {"step": 5, "description": "Identify volatility and variability", "rationale": "Calculate rolling standard deviation to understand how stable or volatile the values are across different time windows."}, {"step": 6, "description": "Create visualizations", "rationale": "Generate line charts, trend lines, and rolling average plots to visually communicate patterns and make insights more intuitive."}, {"step": 7, "description": "Generate summary insights report", "rationale": "Compile key findings about trends, patterns, anomalies, and provide actionable insights based on the analysis."}], "discovery_log": [{"iteration": 1, "tool": "view_file", "input": {"path": "uploads/20260601_171500_8827c032/data.csv"}, "result": "Spreadsheet file (.csv) with 32 lines. First 10 lines:\ndate,value\n2023-01-01,100\n2023-01-02,105\n2023-01-03,102\n2023-01-04,110\n2023-01-05,108\n2023-01-06,115\n2023-01-07,112\n2023-01-08,120\n2023-01-09,118..."}, {"iteration": 1, "tool": "get_file_stats", "input": {"path": "uploads/20260601_171500_8827c032/data.csv"}, "result": "File: uploads/20260601_171500_8827c032/data.csv\nSize: 0.5 KB\nModified: 2026-06-01 17:15\nLines: 31\n"}]}
#
#                   created_at                 updated_at
# 0 2026-06-01 17:15:34.009617 2026-06-01 17:16:32.239709
